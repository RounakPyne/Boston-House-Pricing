# %%
#Supressing warnings 
import warnings
warnings.filterwarnings('ignore')

# %%
#Importing libararies

import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %%
# Importing the dataset
data =pd.read_csv('HousingData.csv')
data.sample(6)
# Out:
#         CRIM    ZN  INDUS  CHAS    NOX     RM   AGE     DIS  RAD  TAX  \
# 221  0.40771   0.0   6.20   1.0  0.507  6.164  91.3  3.0480    8  307
# 294  0.08199   0.0  13.92   NaN  0.437  6.009  42.3  5.5027    4  289
# 63   0.12650  25.0   5.13   0.0  0.453  6.762  43.4  7.9809    8  284
# 235  0.33045   0.0   6.20   0.0  0.507  6.086  61.5  3.6519    8  307
# 488  0.15086   0.0  27.74   0.0  0.609  5.454  92.7  1.8209    4  711
# 99   0.06860   0.0   2.89   0.0  0.445  7.416  62.5  3.4952    2  276
#
#      PTRATIO       B  LSTAT  MEDV
# 221     17.4  395.24  21.46  21.7
# 294     16.0  396.90  10.40  21.7
# 63      19.7  395.58   9.50  25.0
# 235     17.4  376.75  10.88  24.0
# 488     20.1  395.09  18.06  15.2
# 99      18.0  396.90   6.19  33.2

# %%
# Checking Data shape
print('The shape of the data is: ',data.shape)
# Out:
# The shape of the data is:  (506, 14)

# %%
# Creating Bar chart as the Target variable is Continuous to see the distribution.

data['MEDV'].hist(figsize = (18,6), bins = 20)
# Out:
# <Axes: >

# %% [markdown]
# # Dataset essentials

# %%
# getting the data info
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 506 entries, 0 to 505
# Data columns (total 14 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   CRIM     486 non-null    float64
#  1   ZN       486 non-null    float64
#  2   INDUS    486 non-null    float64
#  3   CHAS     486 non-null    float64
#  4   NOX      506 non-null    float64
#  5   RM       506 non-null    float64
#  6   AGE      486 non-null    float64
#  7   DIS      506 non-null    float64
#  8   RAD      506 non-null    int64
#  9   TAX      506 non-null    int64
#  10  PTRATIO  506 non-null    float64
#  11  B        506 non-null    float64
#  12  LSTAT    486 non-null    float64
#  13  MEDV     506 non-null    float64
# dtypes: float64(12), int64(2)
# memory usage: 55.5 KB

# %%
# Lets check the decription of the dataset
data.describe()
# Out:
#              CRIM          ZN       INDUS        CHAS         NOX          RM  \
# count  486.000000  486.000000  486.000000  486.000000  506.000000  506.000000
# mean     3.611874   11.211934   11.083992    0.069959    0.554695    6.284634
# std      8.720192   23.388876    6.835896    0.255340    0.115878    0.702617
# min      0.006320    0.000000    0.460000    0.000000    0.385000    3.561000
# 25%      0.081900    0.000000    5.190000    0.000000    0.449000    5.885500
# 50%      0.253715    0.000000    9.690000    0.000000    0.538000    6.208500
# 75%      3.560263   12.500000   18.100000    0.000000    0.624000    6.623500
# max     88.976200  100.000000   27.740000    1.000000    0.871000    8.780000
#
#               AGE         DIS         RAD         TAX     PTRATIO           B  \
# count  486.000000  506.000000  506.000000  506.000000  506.000000  506.000000
# mean    68.518519    3.795043    9.549407  408.237154   18.455534  356.674032
# ...

# %%
# Check number of unique values 
data.nunique()
# Out:
# CRIM       484
# ZN          26
# INDUS       76
# CHAS         2
# NOX         81
# RM         446
# AGE        348
# DIS        412
# RAD          9
# TAX         66
# PTRATIO     46
# B          357
# LSTAT      438
# MEDV       229
# dtype: int64

# %%
# Checking the missing values
data.isnull().sum()
# Out:
# CRIM       20
# ZN         20
# INDUS      20
# CHAS       20
# NOX         0
# RM          0
# AGE        20
# DIS         0
# RAD         0
# TAX         0
# PTRATIO     0
# B           0
# LSTAT      20
# MEDV        0
# dtype: int64

# %%
# Showing how much missing data is there in precentage
round(data.isnull().sum() / data.shape[0] * 100,2)
# Out:
# CRIM       3.95
# ZN         3.95
# INDUS      3.95
# CHAS       3.95
# NOX        0.00
# RM         0.00
# AGE        3.95
# DIS        0.00
# RAD        0.00
# TAX        0.00
# PTRATIO    0.00
# B          0.00
# LSTAT      3.95
# MEDV       0.00
# dtype: float64

# %%
# Since the missing value is less than 5% it is okay to remove them 
data = data.dropna()

# %%
# Now Checking missing value count
data.isnull().sum()
# Out:
# CRIM       0
# ZN         0
# INDUS      0
# CHAS       0
# NOX        0
# RM         0
# AGE        0
# DIS        0
# RAD        0
# TAX        0
# PTRATIO    0
# B          0
# LSTAT      0
# MEDV       0
# dtype: int64

# %% [markdown]
# # EDA

# %%
f, ax = plt.subplots(figsize=[18, 13])
sns.heatmap(data.corr(), annot=True, fmt=".2f", ax=ax, cmap="magma")
ax.set_title("Correlation Matrix", fontsize=30)
plt.show(block=True)

# %%
# Plotting scatter chart for each predictor vs the target variable['MEDV']
ContinuousCols = ['CRIM', 'ZN', 'INDUS', 'NOX', 'RM', 'AGE', 'DIS', 'TAX','PTRATIO', 'B', 'LSTAT']
for predictor in ContinuousCols:
    data.plot.scatter(x=predictor, y=['MEDV'], figsize=(6,3), title=predictor+" VS "+ 'MEDV')

# %%
# Creating X and Y for train test split

X = data.drop('MEDV',axis=1)
Y = data['MEDV']

# %%
# Train Test Split and checking the shape of the data.
from sklearn.model_selection import train_test_split

x_train, x_test, y_train, y_test = train_test_split(X, Y, test_size=0.30, random_state=42)


print(x_train.shape)
print(x_test.shape)
print(y_train.shape)
print(y_test.shape)
# Out:
# (275, 13)
# (119, 13)
# (275,)
# (119,)

# %%
# Standardizing the dataset

from sklearn.preprocessing import StandardScaler

scaler = StandardScaler()

x_train = scaler.fit_transform(x_train)
x_test = scaler.transform(x_test)

# %%
# Implementing the model

from sklearn.linear_model import LinearRegression

regression = LinearRegression()

# Fitting the model with the training data
regression.fit(x_train,y_train)


from sklearn import metrics
# Measuring Goodness of fit in Training data
print('R2 Value:',metrics.r2_score(y_train, regression.predict(x_train)))


#Printing some sample values of prediction

TargetVariable = 'MEDV'
Predictors = ['CRIM', 'ZN', 'INDUS', 'CHAS', 'NOX', 'RM', 'AGE', 'DIS', 'RAD', 'TAX','PTRATIO', 'B', 'LSTAT']
prediction=regression.predict(x_test)
TestingDataResults=pd.DataFrame(data=x_test, columns=Predictors)
TestingDataResults[TargetVariable]=y_test
TestingDataResults[('Predicted'+TargetVariable)]=np.round(prediction)

# Calculating the error for each row
TestingDataResults['APE']=100 * ((abs(TestingDataResults['MEDV']-TestingDataResults['PredictedMEDV']))/TestingDataResults['MEDV'])

# Printing sample prediction values
print('\n',TestingDataResults[[TargetVariable,'Predicted'+TargetVariable, 'APE']].head())


MAPE=np.mean(TestingDataResults['APE'])

Accuracy =100 - MAPE
print('\nMean Accuracy on test data:', Accuracy) # Can be negative sometimes due to outlier

from sklearn.metrics import mean_squared_error
print('Mean Error on test data:',mean_squared_error(y_test,prediction))


def Accuracy_Score(orig,pred):
    MAPE = np.mean(100 * (np.abs(orig-pred)/orig))
    #print('#'*70,'Accuracy:', 100-MAPE)
    return(100-MAPE)

# Custom Scoring MAPE calculation
from sklearn.metrics import make_scorer
custom_Scoring=make_scorer(Accuracy_Score, greater_is_better=True)

# Custom Scoring MAPE calculation
from sklearn.metrics import make_scorer
custom_Scoring=make_scorer(Accuracy_Score, greater_is_better=True)

# Importing cross validation function from sklearn
from sklearn.model_selection import cross_val_score

# Running 10-Fold Cross validation on a given algorithm
# Passing full data X and y because the K-fold will split the data and automatically choose train/test
Accuracy_Values=cross_val_score(regression, X , Y, cv=10, scoring=custom_Scoring)
print('\nAccuracy values for 10-fold Cross Validation:\n',Accuracy_Values)
print('\nFinal Average Accuracy of the model:', round(Accuracy_Values.mean(),2))
# Out:
# R2 Value: 0.7938985557779464
#
#     MEDV  PredictedMEDV        APE
# 0  24.0           29.0  20.833333
# 1   NaN           17.0        NaN
# 2   NaN           22.0        NaN
# 3  33.4           30.0  10.179641
# 4   NaN           18.0        NaN
#
# Mean Accuracy on test data: 67.78110989578653
# Mean Error on test data: 28.87077192825344
#
# Accuracy values for 10-fold Cross Validation:
#  [90.09634938 87.32118725 89.55947938 87.56918601 86.96698607 87.7068161
#  88.89697244 45.96491796 55.61642904 87.10024117]
#
# Final Average Accuracy of the model: 80.68

# %%
TestingDataResults['PriceAVG']=TestingDataResults['MEDV'].mean()
TestingDataResults.head()
# Out:
#        CRIM        ZN     INDUS      CHAS       NOX        RM       AGE  \
# 0 -0.407163  0.697738  0.597074 -0.264649 -0.788763 -0.081772 -1.419285
# 1 -0.402923  2.053616 -1.371094 -0.264649 -1.246725 -0.560255 -1.786228
# 2 -0.363808 -0.488655 -0.160708 -0.264649 -0.097500 -0.225170 -0.364325
# 3 -0.406475  2.901040 -1.123414 -0.264649 -1.359055  0.033825 -1.810926
# 4 -0.392694 -0.488655 -0.191667 -0.264649  0.256773 -1.021178  0.154334
#
#         DIS       RAD       TAX   PTRATIO         B     LSTAT  MEDV  \
# 0 -0.063856 -0.653281 -0.801502 -0.174522  0.442265 -0.907168  24.0
# 1  3.254000 -0.653281  0.022090 -0.127881  0.400816 -0.695028   NaN
# 2  0.094397 -0.653281 -0.602905 -0.081240  0.441229 -0.031755   NaN
# 3  1.323498 -0.653281 -0.410150 -1.153982  0.448172 -1.113937  33.4
# 4 -0.660132 -0.423693 -0.094732  0.291888  0.436462  0.286455   NaN
#
#    PredictedMEDV        APE   PriceAVG
# 0           29.0  20.833333  22.711111
# 1           17.0        NaN  22.711111
# ...

# %%
# PLotting the scatter chart
plt.scatter(y_test,prediction)

# %%
# plot residual

residuals = y_test-prediction

sns.displot(residuals,kind='kde')

# %%
# prediction vs residuals
# Uniform distribution
plt.scatter(prediction,residuals)

# %%
# New data for prediction

NewData=pd.DataFrame(data=[[0.02985,14,6.87,0,0.468,8.225,54,7.6544,6,355,18.2,456.8,12.68],
                           [0.08624,16,6.66,1,0.568,4.336,62,4.8512,4,655,12.5,424.6,12.382]], columns=Predictors)
NewData_1 = NewData
NewData
# Out:
#       CRIM  ZN  INDUS  CHAS    NOX     RM  AGE     DIS  RAD  TAX  PTRATIO  \
# 0  0.02985  14   6.87     0  0.468  8.225   54  7.6544    6  355     18.2
# 1  0.08624  16   6.66     1  0.568  4.336   62  4.8512    4  655     12.5
#
#        B   LSTAT
# 0  456.8  12.680
# 1  424.6  12.382

# %%
def GeneratePred(inpData):
    new_X=inpData.values
    new_X=scaler.transform(new_X)
    pred=regression.predict(new_X)
    inpData['Price']=pred
    return(inpData)

# %%
GeneratePred(NewData)
# Out:
#       CRIM  ZN  INDUS  CHAS    NOX     RM  AGE     DIS  RAD  TAX  PTRATIO  \
# 0  0.02985  14   6.87     0  0.468  8.225   54  7.6544    6  355     18.2
# 1  0.08624  16   6.66     1  0.568  4.336   62  4.8512    4  655     12.5
#
#        B   LSTAT      Price
# 0  456.8  12.680  28.125694
# 1  424.6  12.382  14.149997

# %%
# transforming the data for pickle deployment
NewData_1 = scaler.transform(NewData_1)

# %% [markdown]
# ## Pickling the model file for Deployment

# %%
import pickle

pickle.dump(regression,open('regmodel.pkl','wb'))# write bite

# %%
pickled_model = pickle.load(open('regmodel.pkl','rb'))

# %%
pickled_model.predict(NewData_1)
# Out:
# array([28.12569406, 14.14999724])
